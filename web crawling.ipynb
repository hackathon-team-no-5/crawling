# %%
#중고나라 - 고가 중고 (가방, 시계, 의류, 신발)
#가방
from selenium import webdriver
import time

driver = webdriver.Chrome('/usr/local/bin/chromedriver')
driver.get('https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=782%26search.boardtype=L')
bb2 = []
dataset = []
time.sleep(2)

driver.switch_to.frame("cafe_main")
for l in range(1,5):
    tag = driver.find_elements_by_xpath('//div[@class="article-board m-tcol-c"]//table/tbody/tr')
    bb2 = tag
    time.sleep(2)
    
    for i in range(len(bb2)):
        dataset.append(bb2[i].text)

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)

driver.quit()

# %%
data = len(dataset)-1
while data >= 0:
    if data % 2 == 1:
        del dataset[data]
    data-=1
print(dataset[:30])
# Out:
# ['공지\n월 5천원대 통신비 가입하면 다양한 사은품부터 상품권까지 [1]\n중나트벤이군\n2021.08.02. 2.4만', '공지\n가성비 좋은 인기 S폰 5종! 블랙으로만 싹! 10만원대부터~\n중나트벤이군\n2021.08.04. 4.1만', '공지\n최고급 인기 바이크 탈 사람!! 바이크 핫딜 모음전~\n중나트벤이군\n2021.08.10. 5,338', '공지\n[꿀딜특구 - 50%할인] 호브로 x 진로 콜라보 꺼비 마사지건\n중나트벤이군\n2021.08.17. 1,245', '공지\n구매 게시글 접근 사기 주의\nnew\n중나스탭\n2021.08.18. 3,414', '공지\n[마감 10일전] 매직점프 게임 인증!! 지금 참여하면 100% 당첨각!!\n중나트벤이군\n2021.07.20. 1.9만', '공지\n명품 구찌 브라운 벨트 새상품 최저가 남은 재고 딱 1개\nnew\n비밀고릴라\n2021.08.18. 533', '공지\n머지포인트 거래를 자제해 주세요!\n중나중나지기\n2021.08.15. 6,884', "공지\n★인증이벤트★ '네이버페이' 받아가세요~! 펑펑 쏜다! [51]\n중나트벤이짱\n2021.08.12. 1,699", '공지\n중고나라 통합 운영정책(2020.12.04개정)\n중나중나지기\n2020.12.04. 21만', '860966293\n생로랑 엔벨롭 클러치\n판매\n사진\nnew\nchoijw170119\n02:04 0', '860966233\n발렌시아가 폰홀더백 블랙\n판매\n사진\nnew\njjammes\n02:03 3', '860966054\n드래곤백 캐니지 스몰(새제품)\n판매\n사진\nnew\nmamabees\n02:00 7', '860965914\n루이비통 알마bb다미에\n판매\n사진\nnew\n횰히\n01:57 8', '860965792\n(69만) 구찌 미니 체인백\n판매\n사진\nnew\nRro A\n01:55 6', '860965772\n(69만) 구찌 체인 미니백\n판매\n사진\nnew\nRro A\n01:
# ...

# %%
list = len(dataset)-1
while list >= 0:
    if '공지' in dataset[list]:
        del dataset[list]
    list -= 1
print(dataset[:15])
# Out:
# ['860966293\n생로랑 엔벨롭 클러치\n판매\n사진\nnew\nchoijw170119\n02:04 0', '860966233\n발렌시아가 폰홀더백 블랙\n판매\n사진\nnew\njjammes\n02:03 3', '860966054\n드래곤백 캐니지 스몰(새제품)\n판매\n사진\nnew\nmamabees\n02:00 7', '860965914\n루이비통 알마bb다미에\n판매\n사진\nnew\n횰히\n01:57 8', '860965792\n(69만) 구찌 미니 체인백\n판매\n사진\nnew\nRro A\n01:55 6', '860965772\n(69만) 구찌 체인 미니백\n판매\n사진\nnew\nRro A\n01:55 3', '860965710\n샤넬 비지니스 어피니티 스몰\n판매\n사진\nnew\n횰히\n01:53 11', '860965708\n[미개봉] 루이비통 알마 BB 8종 보유(정품) 팝니다\n판매 안전\n사진\nnew\n맨유의 반할\n01:53 3', '860965598\n멀버리 윌로우백 라지 메로나색상\n판매\n사진\nnew\noption09\n01:52 4', '860965588\n로저비비에 메탈플라워버클 클러치(크로스체인O숄더O)\n판매\n사진\nnew\noption09\n01:51 6', '860965481\n샤넬 클래식 미듐\n판매\n사진\nnew\n나나\n01:50 6', '860965266\n버버리 정품 스카프\n판매\n사진\nnew\n까만뽈래기\n01:46 3', '860965197\n데상트 백팩\n판매\n사진\nnew\n어멘다\n01:45 4', '860965164\nFossil 파슬 메신저백(크로스백 겸용)\n판매 안전\n사진\nnew\nkwj0728\n01:44 2', '860965051\n정품 샤넬 제니 핑크 캐비어 금장 woc 280만\n판매\n사진\nnew\n애기애깅님\n01:42 4']

# %%
datalist = []
for r in range(len(dataset)):
    a = dataset[r].split('\n')
    if len(a) == 4:
        b = a[3].split(' ')
        del a[3]
        for i in b:
            a.append(i)
        datalist.append(a)
    elif len(a) == 6:
        b = a[5].split(' ')
        del a[5]
        for i in b:
            a.append(i)
        datalist.append(a)
    else:
        b = a[4].split(' ')
        del a[4]
        for i in b:
            a.append(i)
        datalist.append(a)
datalist
# Out:
# [['860966293', '생로랑 엔벨롭 클러치', '판매', '사진', 'choijw170119', '02:04 0', 'new'],
#  ['860966233', '발렌시아가 폰홀더백 블랙', '판매', '사진', 'jjammes', '02:03 3', 'new'],
#  ['860966054', '드래곤백 캐니지 스몰(새제품)', '판매', '사진', 'mamabees', '02:00 7', 'new'],
#  ['860965914', '루이비통 알마bb다미에', '판매', '사진', '횰히', '01:57 8', 'new'],
#  ['860965792', '(69만) 구찌 미니 체인백', '판매', '사진', 'Rro A', '01:55 6', 'new'],
#  ['860965772', '(69만) 구찌 체인 미니백', '판매', '사진', 'Rro A', '01:55 3', 'new'],
#  ['860965710', '샤넬 비지니스 어피니티 스몰', '판매', '사진', '횰히', '01:53 11', 'new'],
#  ['860965708',
#   '[미개봉] 루이비통 알마 BB 8종 보유(정품) 팝니다',
#   '판매 안전',
#   '사진',
#   '맨유의 반할',
#   '01:53 3',
#   'new'],
#  ['860965598', '멀버리 윌로우백 라지 메로나색상', '판매', '사진', 'option09', '01:52 4', 'new'],
#  ['860965588',
#   '로저비비에 메탈플라워버클 클러치(크로스체인O숄더O)',
#   '판매',
#   '사진',
#   'option09',
#   '01:51 6',
#   'new'],
#  ['860965481', '샤넬 클래식 미듐', '판매', '사진', '나나', '01:50 6', 'new'],
#  ['860965266', '버버리 정품 스카프', '판매', '사진', '까만뽈래기', '01:46 3', 'new'],
# ...

# %%
datalen = []
for r in range(len(datalist)):
    tmp = []
    tm = datalist[r]
    for t in range(len(tm)):
        if t == 3 and tm[t] != '사진':
            tmp.append('')
        tmp.append(tm[t])
        
    datalen.append(tmp)
datalen

datalen2 = datalen
bag_dataset = []
for r in range(len(datalen2)):
    tmp = []
    tm = datalen2[r]
    for t in range(len(tm)):
        if t == 6 and tm[t] != 'new':
            tmp.append('')
        tmp.append(tm[t])
        
    bag_dataset.append(tmp)
bag_dataset
# Out:
# [['860966293', '생로랑 엔벨롭 클러치', '판매', '사진', 'choijw170119', '02:04 0', 'new'],
#  ['860966233', '발렌시아가 폰홀더백 블랙', '판매', '사진', 'jjammes', '02:03 3', 'new'],
#  ['860966054', '드래곤백 캐니지 스몰(새제품)', '판매', '사진', 'mamabees', '02:00 7', 'new'],
#  ['860965914', '루이비통 알마bb다미에', '판매', '사진', '횰히', '01:57 8', 'new'],
#  ['860965792', '(69만) 구찌 미니 체인백', '판매', '사진', 'Rro A', '01:55 6', 'new'],
#  ['860965772', '(69만) 구찌 체인 미니백', '판매', '사진', 'Rro A', '01:55 3', 'new'],
#  ['860965710', '샤넬 비지니스 어피니티 스몰', '판매', '사진', '횰히', '01:53 11', 'new'],
#  ['860965708',
#   '[미개봉] 루이비통 알마 BB 8종 보유(정품) 팝니다',
#   '판매 안전',
#   '사진',
#   '맨유의 반할',
#   '01:53 3',
#   'new'],
#  ['860965598', '멀버리 윌로우백 라지 메로나색상', '판매', '사진', 'option09', '01:52 4', 'new'],
#  ['860965588',
#   '로저비비에 메탈플라워버클 클러치(크로스체인O숄더O)',
#   '판매',
#   '사진',
#   'option09',
#   '01:51 6',
#   'new'],
#  ['860965481', '샤넬 클래식 미듐', '판매', '사진', '나나', '01:50 6', 'new'],
#  ['860965266', '버버리 정품 스카프', '판매', '사진', '까만뽈래기', '01:46 3', 'new'],
# ...

# %%
for r in bag_dataset:
    if "'" in r[1]:
        print(bag_dataset.index(r))

# %%
import pymysql

connect = pymysql.connect(host='221.168.38.225', user='fintech5', password='fintech5', db='Revendor', charset='utf8mb4')
cursor = connect.cursor()

for r in bag_dataset:
    unum = int(r[0])
    title = str(r[1])
    bs = str(r[2])
    photo = str(r[3])
    uname = str(r[4])
    utime = str(r[5])
    unew = str(r[6])
    
    sql = """insert into bag
    (unum, title, bs, photo, uname, utime, unew) 
    values ('%d', '%s', '%s', '%s', '%s', '%s', '%s')
    """ % (unum, title, bs, photo, uname, utime, unew)

    cursor.execute(sql)
    connect.commit()
connect.close()

# %%
dataset[:30]
# Out:
# ['860966293\n생로랑 엔벨롭 클러치\n판매\n사진\nnew\nchoijw170119\n02:04 0',
#  '860966233\n발렌시아가 폰홀더백 블랙\n판매\n사진\nnew\njjammes\n02:03 3',
#  '860966054\n드래곤백 캐니지 스몰(새제품)\n판매\n사진\nnew\nmamabees\n02:00 7',
#  '860965914\n루이비통 알마bb다미에\n판매\n사진\nnew\n횰히\n01:57 8',
#  '860965792\n(69만) 구찌 미니 체인백\n판매\n사진\nnew\nRro A\n01:55 6',
#  '860965772\n(69만) 구찌 체인 미니백\n판매\n사진\nnew\nRro A\n01:55 3',
#  '860965710\n샤넬 비지니스 어피니티 스몰\n판매\n사진\nnew\n횰히\n01:53 11',
#  '860965708\n[미개봉] 루이비통 알마 BB 8종 보유(정품) 팝니다\n판매 안전\n사진\nnew\n맨유의 반할\n01:53 3',
#  '860965598\n멀버리 윌로우백 라지 메로나색상\n판매\n사진\nnew\noption09\n01:52 4',
#  '860965588\n로저비비에 메탈플라워버클 클러치(크로스체인O숄더O)\n판매\n사진\nnew\noption09\n01:51 6',
#  '860965481\n샤넬 클래식 미듐\n판매\n사진\nnew\n나나\n01:50 6',
#  '860965266\n버버리 정품 스카프\n판매\n사진\nnew\n까만뽈래기\n01:46 3',
#  '860965197\n데상트 백팩\n판매\n사진\nnew\n어멘다\n01:45 4',
#  '860965164\nFossil 파슬 메신저백(크로스백 겸용)\n판매 안전\n사진\nnew\nkwj0728\n01:44 2',
#  '860965051\n정품 샤넬 제니 핑크 캐비어 금장 woc 280만\n판매\n사진\nnew\n애기애깅님\n01:42 4',
# ...

# %%
#시계
from selenium import webdriver
import time

driver = webdriver.Chrome('/usr/local/bin/chromedriver')
driver.get('https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=1011%26search.boardtype=L')
bb2 = []
dataset = []
time.sleep(2)

driver.switch_to.frame("cafe_main")
for l in range(1,5):
    tag = driver.find_elements_by_xpath('//div[@class="article-board m-tcol-c"]//table/tbody/tr')
    bb2 = tag
    time.sleep(2)
    
    for i in range(len(bb2)):
        dataset.append(bb2[i].text)

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)

driver.quit()

# %%
data = len(dataset)-1
while data >= 0:
    if data % 2 == 1:
        del dataset[data]
    data-=1
print(dataset[:30])
# Out:
# ['공지\n월 5천원대 통신비 가입하면 다양한 사은품부터 상품권까지 [1]\n중나트벤이군\n2021.08.02. 2.4만', '공지\n가성비 좋은 인기 S폰 5종! 블랙으로만 싹! 10만원대부터~\n중나트벤이군\n2021.08.04. 4.1만', '공지\n최고급 인기 바이크 탈 사람!! 바이크 핫딜 모음전~\n중나트벤이군\n2021.08.10. 5,338', '공지\n[꿀딜특구 - 50%할인] 호브로 x 진로 콜라보 꺼비 마사지건\n중나트벤이군\n2021.08.17. 1,245', '공지\n구매 게시글 접근 사기 주의\nnew\n중나스탭\n2021.08.18. 3,414', '공지\n[마감 10일전] 매직점프 게임 인증!! 지금 참여하면 100% 당첨각!!\n중나트벤이군\n2021.07.20. 1.9만', '공지\n명품 구찌 브라운 벨트 새상품 최저가 남은 재고 딱 1개\nnew\n비밀고릴라\n2021.08.18. 533', '공지\n머지포인트 거래를 자제해 주세요!\n중나중나지기\n2021.08.15. 6,884', "공지\n★인증이벤트★ '네이버페이' 받아가세요~! 펑펑 쏜다! [51]\n중나트벤이짱\n2021.08.12. 1,699", '공지\n중고나라 통합 운영정책(2020.12.04개정)\n중나중나지기\n2020.12.04. 21만', '860966347\n태그호이어 까레라 호이어02 크로노그래프 판매\n판매\n사진\nnew\n가즈아김\n02:05 2', '860966038\n정품 서브마리너 1116610LN 판매,교환합니다.\n판매\n사진\nnew\nwsx1124\n01:59 7', '860965802\n80년대 오메가 씨마스터 36mm 빈티지\n판매\n사진\nnew\n린스먹고쿨럭\n01:55 6', '860965758\n까르띠에 총정리판매 각20만\n판매\n사진\nnew\n카사노바\n01:54 2', '860965722\nGc 시계 미개봉 팝니다\n판매 안전\n사진\nnew\n맨유의 반할\n01:54 2', '860965689\n[매입] 로렉스
# ...

# %%
list = len(dataset)-1
while list >= 0:
    if '공지' in dataset[list]:
        del dataset[list]
    list -= 1
print(dataset[:15])
# Out:
# ['860966347\n태그호이어 까레라 호이어02 크로노그래프 판매\n판매\n사진\nnew\n가즈아김\n02:05 2', '860966038\n정품 서브마리너 1116610LN 판매,교환합니다.\n판매\n사진\nnew\nwsx1124\n01:59 7', '860965802\n80년대 오메가 씨마스터 36mm 빈티지\n판매\n사진\nnew\n린스먹고쿨럭\n01:55 6', '860965758\n까르띠에 총정리판매 각20만\n판매\n사진\nnew\n카사노바\n01:54 2', '860965722\nGc 시계 미개봉 팝니다\n판매 안전\n사진\nnew\n맨유의 반할\n01:54 2', '860965689\n[매입] 로렉스 Gmt2 스틸,콤비,금통 삽니다 구형도삽니다~\n판매\n사진\nnew\n로렉스전국지점\n01:53 2', '860965659\n울프 10구 케이스\n판매\n사진\nnew\n비엠인\n01:53 1', '860965484\n16233,서브마리너 여분코 판매합니다.\n판매\n사진\nnew\nwsx1124\n01:50 1', '860965386\n해밀턴 재즈마스터 오픈하트 40mm\n판매 안전\n사진\nnew\npmpr\n01:48 4', '860965142\n[매입] 오메마피게 모든 모델 전부 최고가 매입합니다\n판매\n사진\nnew\n로렉스매입\n01:44 1', '860965113\n루치아노, OST, 코스모폴리탄 여성, 남성 메탈 시계 싸게 판매합니다\n판매\n사진\nnew\n여시남\n01:43 2', '860964662\n[매입] 로렉스 스카이드웰러 스틸,콤비,금통 삽니다 구형도삽니다~\n판매\n사진\nnew\n로렉스전국지점\n01:36 2', '860964253\n그랜드세이코 SBGP013 청판 쿼츠 모델 판매합니다(7월 29일 구입)\n판매\n사진\nnew\n스프렌제리\n01:30 19', '860963852\n브라이틀링 총정리판매 각20만\n판매\n사진\nnew\n카사노바\n01:24 2', '860963678\n[매입] 파텍필립 모든
# ...

# %%
datalist = []
for r in range(len(dataset)):
    a = dataset[r].split('\n')
    if len(a) == 4:
        b = a[3].split(' ')
        del a[3]
        for i in b:
            a.append(i)
        datalist.append(a)
    elif len(a) == 6:
        b = a[5].split(' ')
        del a[5]
        for i in b:
            a.append(i)
        datalist.append(a)
    else:
        b = a[4].split(' ')
        del a[4]
        for i in b:
            a.append(i)
        datalist.append(a)
datalist
# Out:
# [['860966347',
#   '태그호이어 까레라 호이어02 크로노그래프 판매',
#   '판매',
#   '사진',
#   '가즈아김',
#   '02:05 2',
#   'new'],
#  ['860966038',
#   '정품 서브마리너 1116610LN 판매,교환합니다.',
#   '판매',
#   '사진',
#   'wsx1124',
#   '01:59 7',
#   'new'],
#  ['860965802',
#   '80년대 오메가 씨마스터 36mm 빈티지',
#   '판매',
#   '사진',
#   '린스먹고쿨럭',
#   '01:55 6',
#   'new'],
#  ['860965758', '까르띠에 총정리판매 각20만', '판매', '사진', '카사노바', '01:54 2', 'new'],
#  ['860965722', 'Gc 시계 미개봉 팝니다', '판매 안전', '사진', '맨유의 반할', '01:54 2', 'new'],
#  ['860965689',
#   '[매입] 로렉스 Gmt2 스틸,콤비,금통 삽니다 구형도삽니다~',
#   '판매',
#   '사진',
#   '로렉스전국지점',
#   '01:53 2',
#   'new'],
#  ['860965659', '울프 10구 케이스', '판매', '사진', '비엠인', '01:53 1', 'new'],
#  ['860965484',
#   '16233,서브마리너 여분코 판매합니다.',
#   '판매',
#   '사진',
#   'wsx1124',
#   '01:50 1',
#   'new'],
#  ['860965386', '해밀턴 재즈마스터 오픈하트 40mm', '판매 안전', '사진', 'pmpr', '01:48 4', 'new'],
#  ['860965142',
#   '[매입] 오메마피게 모든 모델 전부 최고가 매입합니다',
#   '판매',
#   '사진',
#   '로렉스매입',
#   '01:44 1',
#   'new'],
#  ['860965113',
# ...

# %%
datalen = []
for r in range(len(datalist)):
    tmp = []
    tm = datalist[r]
    for t in range(len(tm)):
        if t == 3 and tm[t] != '사진':
            tmp.append('')
        tmp.append(tm[t])
        
    datalen.append(tmp)
datalen

datalen2 = datalen
watch_dataset = []
for r in range(len(datalen2)):
    tmp = []
    tm = datalen2[r]
    for t in range(len(tm)):
        if t == 6 and tm[t] != 'new':
            tmp.append('')
        tmp.append(tm[t])
        
    watch_dataset.append(tmp)
watch_dataset
# Out:
# [['860966347',
#   '태그호이어 까레라 호이어02 크로노그래프 판매',
#   '판매',
#   '사진',
#   '가즈아김',
#   '02:05 2',
#   'new'],
#  ['860966038',
#   '정품 서브마리너 1116610LN 판매,교환합니다.',
#   '판매',
#   '사진',
#   'wsx1124',
#   '01:59 7',
#   'new'],
#  ['860965802',
#   '80년대 오메가 씨마스터 36mm 빈티지',
#   '판매',
#   '사진',
#   '린스먹고쿨럭',
#   '01:55 6',
#   'new'],
#  ['860965758', '까르띠에 총정리판매 각20만', '판매', '사진', '카사노바', '01:54 2', 'new'],
#  ['860965722', 'Gc 시계 미개봉 팝니다', '판매 안전', '사진', '맨유의 반할', '01:54 2', 'new'],
#  ['860965689',
#   '[매입] 로렉스 Gmt2 스틸,콤비,금통 삽니다 구형도삽니다~',
#   '판매',
#   '사진',
#   '로렉스전국지점',
#   '01:53 2',
#   'new'],
#  ['860965659', '울프 10구 케이스', '판매', '사진', '비엠인', '01:53 1', 'new'],
#  ['860965484',
#   '16233,서브마리너 여분코 판매합니다.',
#   '판매',
#   '사진',
#   'wsx1124',
#   '01:50 1',
#   'new'],
#  ['860965386', '해밀턴 재즈마스터 오픈하트 40mm', '판매 안전', '사진', 'pmpr', '01:48 4', 'new'],
#  ['860965142',
#   '[매입] 오메마피게 모든 모델 전부 최고가 매입합니다',
#   '판매',
#   '사진',
#   '로렉스매입',
#   '01:44 1',
#   'new'],
#  ['860965113',
# ...

# %%
import pymysql

connect = pymysql.connect(host='221.168.38.225', user='fintech5', password='fintech5', db='Revendor', charset='utf8mb4')
cursor = connect.cursor()

for r in watch_dataset:
    unum = int(r[0])
    title = str(r[1])
    bs = str(r[2])
    photo = str(r[3])
    uname = str(r[4])
    utime = str(r[5])
    unew = str(r[6])
    
    sql = """insert into watch
    (unum, title, bs, photo, uname, utime, unew) 
    values ('%d', '%s', '%s', '%s', '%s', '%s', '%s')
    """ % (unum, title, bs, photo, uname, utime, unew)

    cursor.execute(sql)
    connect.commit()
connect.close()

# %%
#신발
from selenium import webdriver
import time

driver = webdriver.Chrome('/usr/local/bin/chromedriver')
driver.get('https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=1010%26search.boardtype=L')
bb2 = []
dataset = []
time.sleep(2)

driver.switch_to.frame("cafe_main")
for l in range(1,5):
    tag = driver.find_elements_by_xpath('//div[@class="article-board m-tcol-c"]//table/tbody/tr')
    bb2 = tag
    time.sleep(2)
    
    for i in range(len(bb2)):
        dataset.append(bb2[i].text)

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)

driver.quit()

data = len(dataset)-1
while data >= 0:
    if data % 2 == 1:
        del dataset[data]
    data-=1

list = len(dataset)-1
while list >= 0:
    if '공지' in dataset[list]:
        del dataset[list]
    list -= 1
    
    datalist = []
for r in range(len(dataset)):
    a = dataset[r].split('\n')
    if len(a) == 4:
        b = a[3].split(' ')
        del a[3]
        for i in b:
            a.append(i)
        datalist.append(a)
    elif len(a) == 6:
        b = a[5].split(' ')
        del a[5]
        for i in b:
            a.append(i)
        datalist.append(a)
    else:
        b = a[4].split(' ')
        del a[4]
        for i in b:
            a.append(i)
        datalist.append(a)
datalist

datalen = []
for r in range(len(datalist)):
    tmp = []
    tm = datalist[r]
    for t in range(len(tm)):
        if t == 3 and tm[t] != '사진':
            tmp.append('')
        tmp.append(tm[t])
        
    datalen.append(tmp)
datalen

datalen2 = datalen
shoes_dataset = []
for r in range(len(datalen2)):
    tmp = []
    tm = datalen2[r]
    for t in range(len(tm)):
        if t == 6 and tm[t] != 'new':
            tmp.append('')
        tmp.append(tm[t])
        
    shoes_dataset.append(tmp)
shoes_dataset
# Out:
# [['860965433', '(새제품 265) 구찌 스니커즈 팝니다', '판매', '사진', 'RXㅡ78', '01:49 2', 'new'],
#  ['860965388',
#   '나이키 피스마이너스원 에어포스2 흰검 265 판매합니다',
#   '판매',
#   '사진',
#   '메줭느낌나는데',
#   '01:48 2',
#   'new'],
#  ['860964842',
#   '발렌시아가 트랙슈즈 검파초 41size 판매합니다',
#   '판매',
#   '사진',
#   '윤창이윤창',
#   '01:39 5',
#   'new'],
#  ['860964635',
#   '알렉산더 맥퀸 오버솔 39사이즈 ((( 판매중 )))',
#   '판매',
#   '사진',
#   '대구 전당포',
#   '01:36 4',
#   'new'],
#  ['860964563',
#   '루이비통 룩셈부르크 스니커즈 7사이즈 ((( 판매중 )))',
#   '판매',
#   '사진',
#   '대구 전당포',
#   '01:35 3',
#   'new'],
#  ['860964192',
#   '골든구스 실버텝 41사이즈 상태좋음',
#   '판매',
#   '사진',
#   '슬기로운비움생활',
#   '01:29 2',
#   'new'],
#  ['860963524',
#   '커먼프로젝트 아킬레스 로우 43 (280)',
#   '판매',
#   '사진',
#   'BKq22',
#   '01:20 4',
#   'new'],
#  ['860963440', '나이키 사카이 울프그레이 265', '판매', '사진', 'gup17', '01:19 5', 'new'],
#  ['860963178',
#   '구찌 라이톤 띠로고 운동화 UK8 270-275',
#   '판매',
#   '사진',
#   'GroomyDay',
#   '01:15 5',
#   'new'],
# ...

# %%
import pymysql

connect = pymysql.connect(host='221.168.38.225', user='fintech5', password='fintech5', db='Revendor', charset='utf8mb4')
cursor = connect.cursor()

for r in shoes_dataset:
    unum = int(r[0])
    title = str(r[1])
    bs = str(r[2])
    photo = str(r[3])
    uname = str(r[4])
    utime = str(r[5])
    unew = str(r[6])
    
    sql = """insert into shoes
    (unum, title, bs, photo, uname, utime, unew) 
    values ('%d', '%s', '%s', '%s', '%s', '%s', '%s')
    """ % (unum, title, bs, photo, uname, utime, unew)

    cursor.execute(sql)
    connect.commit()
connect.close()

# %%
#의류

from selenium import webdriver
import time

driver = webdriver.Chrome('/usr/local/bin/chromedriver')
driver.get('https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=1007%26search.boardtype=L')
bb2 = []
dataset = []
time.sleep(2)

driver.switch_to.frame("cafe_main")
for l in range(1,5):
    tag = driver.find_elements_by_xpath('//div[@class="article-board m-tcol-c"]//table/tbody/tr')
    bb2 = tag
    time.sleep(2)
    
    for i in range(len(bb2)):
        dataset.append(bb2[i].text)

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)

driver.quit()

data = len(dataset)-1
while data >= 0:
    if data % 2 == 1:
        del dataset[data]
    data-=1

list = len(dataset)-1
while list >= 0:
    if '공지' in dataset[list]:
        del dataset[list]
    list -= 1
    
    datalist = []
for r in range(len(dataset)):
    a = dataset[r].split('\n')
    if len(a) == 4:
        b = a[3].split(' ')
        del a[3]
        for i in b:
            a.append(i)
        datalist.append(a)
    elif len(a) == 6:
        b = a[5].split(' ')
        del a[5]
        for i in b:
            a.append(i)
        datalist.append(a)
    else:
        b = a[4].split(' ')
        del a[4]
        for i in b:
            a.append(i)
        datalist.append(a)
datalist

datalen = []
for r in range(len(datalist)):
    tmp = []
    tm = datalist[r]
    for t in range(len(tm)):
        if t == 3 and tm[t] != '사진':
            tmp.append('')
        tmp.append(tm[t])
        
    datalen.append(tmp)
datalen

datalen2 = datalen
clothes_dataset = []
for r in range(len(datalen2)):
    tmp = []
    tm = datalen2[r]
    for t in range(len(tm)):
        if t == 6 and tm[t] != 'new':
            tmp.append('')
        tmp.append(tm[t])
        
    clothes_dataset.append(tmp)
clothes_dataset
# Out:
# [['860965639', '쟈딕앤볼테르 원피스(새상품)', '판매', '사진', 'option09', '01:52 4', 'new'],
#  ['860965630', '산드로 원피스 (새상품)', '판매', '사진', 'option09', '01:52 2', 'new'],
#  ['860965627',
#   '이자벨마랑 발레리 등 스커트3종 새상품',
#   '판매',
#   '사진',
#   'option09',
#   '01:52 6',
#   'new'],
#  ['860965493', 'AX알마니 베스트', '판매', '사진', 'powerbeat97', '01:50 1', 'new'],
#  ['860965010',
#   '마쥬 레드 타탄 체크 스커트 36 사이즈 새 상품',
#   '판매',
#   '사진',
#   'sweetly06',
#   '01:42 3',
#   'new'],
#  ['860964163', '랄프로렌,빈폴등', '판매', '사진', 'momentumkim', '01:28 2', 'new'],
#  ['860964110', '리포메이션 원피스', '판매 안전', '사진', '도비는자유에요미', '01:28 3', 'new'],
#  ['860964100',
#   '메리노 울 NYU 브이넥 가디건 풀오버 S (44-날씬55)',
#   '판매',
#   '사진',
#   'hnee1',
#   '01:27 3',
#   'new'],
#  ['860963997',
#   '쥬시 꾸뛰르 다크네이비 수건 집업 실버 핑크 큐빅 P(44-55)',
#   '판매',
#   '사진',
#   'hnee1',
#   '01:26 2',
#   'new'],
#  ['860963870',
#   '[가격내림] 베트멍 그린 롱 후드 후드티 드레스 원피스',
#   '판매',
#   '사진',
#   '인절미미쨩',
#   '01:24 5',
#   'new'],
# ...

# %%
import pymysql

connect = pymysql.connect(host='221.168.38.225', user='fintech5', password='fintech5', db='Revendor', charset='utf8mb4')
cursor = connect.cursor()

for r in clothes_dataset:
    unum = int(r[0])
    title = str(r[1])
    bs = str(r[2])
    photo = str(r[3])
    uname = str(r[4])
    utime = str(r[5])
    unew = str(r[6])
    
    sql = """insert into clothes
    (unum, title, bs, photo, uname, utime, unew) 
    values ('%d', '%s', '%s', '%s', '%s', '%s', '%s')
    """ % (unum, title, bs, photo, uname, utime, unew)

    cursor.execute(sql)
    connect.commit()
connect.close()

# %%
import requests
from bs4 import BeautifulSoup

# %%
# "명품" 키워드로 검색
url = "https://m.cafe.naver.com/ArticleSearchList.nhn?search.query=%EB%AA%85%ED%92%88&search.menuid=782&search.searchBy=0&search.sortBy=date&search.clubid=10050146"

# %%
response = requests.get(url)
response.status_code, response
# Out:
# (200, <Response [200]>)

# %%
dom = BeautifulSoup(response.text, "html.parser")
post_elements = dom.select("ul.list_tit li")
len(post_elements)
# Out:
# 20

# %%
post_element = post_elements[0]
post_element
# Out:
# <li>
# <a href="/ArticleRead.nhn?clubid=10050146&amp;menuid=782&amp;articleid=860751838&amp;query=%EB%AA%85%ED%92%88&amp;art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtaW5DYWZlLXNlYXJjaC1saXN0.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjg2MDc1MTgzOCwiaXNzdWVkQXQiOjE2MjkyMjg2NzU2NzAsImNhZmVJZCI6MTAwNTAxNDZ9.QBgyzgt3D3sSEQvL8I_QwdZ73b_W0F7BqNQ8cv06vu4" onclick="nclk(this, 'cfs*n.list', '860751838', '')">
# <div class="item ">
# <div class="thmb"><img alt="썸네일" height="65" src="https://cafeptthumb-phinf.pstatic.net/MjAyMTA4MThfMjQ4/MDAxNjI5MjEzOTMxMzAx.hpc9l0dXujgSgVx3LyDwFvUpOG5QZEGFF9ulZkIJjUYg.R6QP7-V2OdcRrN0GIg3xVc7z0vEztNdIavLdYJOznpIg.JPEG/KakaoTalk_20210628_013916813.jpg?type=f100_100" width="65"/></div>
# <div class="tit">
# <span class="icon_txt">판매</span>
# <h3>[<b>명품</b>가방판매] 루이비통 에바 클러치 디테일사진 (풀박스)</h3>
# <span class="desc_attach">
# <span class="ico_cafe ico_new"><span class="blind">New</span></span>
# </span>
# </div>
# </div>
# </a>
# ...

# %%
title = post_element.select_one("h3").text
url = post_element.select_one("a").get("href")   #href는 속성
nickname = post_element.select_one("span.name").text
created_at = post_element.select_one("span.time").text
count = post_element.select_one("span.no").text.split(" ")[-1]

print((title, url, nickname, created_at, count))
# Out:
# ('[명품가방판매] 루이비통 에바 클러치 디테일사진 (풀박스)', '/ArticleRead.nhn?clubid=10050146&menuid=782&articleid=860751838&query=%EB%AA%85%ED%92%88&art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtaW5DYWZlLXNlYXJjaC1saXN0.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjg2MDc1MTgzOCwiaXNzdWVkQXQiOjE2MjkyMjg2NzU2NzAsImNhZmVJZCI6MTAwNTAxNDZ9.QBgyzgt3D3sSEQvL8I_QwdZ73b_W0F7BqNQ8cv06vu4', '내가쩨일잘놔가', '00:25', '45')

# %%
post_element.contents
# Out:
# ['\n',
#  <a href="/ArticleRead.nhn?clubid=10050146&amp;menuid=782&amp;articleid=860751838&amp;query=%EB%AA%85%ED%92%88&amp;art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtaW5DYWZlLXNlYXJjaC1saXN0.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjg2MDc1MTgzOCwiaXNzdWVkQXQiOjE2MjkyMjg2NzU2NzAsImNhZmVJZCI6MTAwNTAxNDZ9.QBgyzgt3D3sSEQvL8I_QwdZ73b_W0F7BqNQ8cv06vu4" onclick="nclk(this, 'cfs*n.list', '860751838', '')">
#  <div class="item ">
#  <div class="thmb"><img alt="썸네일" height="65" src="https://cafeptthumb-phinf.pstatic.net/MjAyMTA4MThfMjQ4/MDAxNjI5MjEzOTMxMzAx.hpc9l0dXujgSgVx3LyDwFvUpOG5QZEGFF9ulZkIJjUYg.R6QP7-V2OdcRrN0GIg3xVc7z0vEztNdIavLdYJOznpIg.JPEG/KakaoTalk_20210628_013916813.jpg?type=f100_100" width="65"/></div>
#  <div class="tit">
#  <span class="icon_txt">판매</span>
#  <h3>[<b>명품</b>가방판매] 루이비통 에바 클러치 디테일사진 (풀박스)</h3>
#  <span class="desc_attach">
#  <span class="ico_cafe ico_new"><span class="blind">New</span></span>
#  </span>
#  </div>
#  </div>
# ...

# %%
for post_element in post_elements:
    title = post_element.select_one("h3").text
    url = post_element.select_one("a").get("href")
    nickname = post_element.select_one("span.name").text
    created_at = post_element.select_one("span.time").text
    count = post_element.select_one("span.no").text.split(" ")[-1]
    
    print((title, url, nickname, created_at, count))
# Out:
# ('[명품가방판매] 루이비통 에바 클러치 디테일사진 (풀박스)', '/ArticleRead.nhn?clubid=10050146&menuid=782&articleid=860751838&query=%EB%AA%85%ED%92%88&art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtaW5DYWZlLXNlYXJjaC1saXN0.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjg2MDc1MTgzOCwiaXNzdWVkQXQiOjE2MjkyMjg2NzU2NzAsImNhZmVJZCI6MTAwNTAxNDZ9.QBgyzgt3D3sSEQvL8I_QwdZ73b_W0F7BqNQ8cv06vu4', '내가쩨일잘놔가', '00:25', '45')
# ('[명품가방판매] 구찌 포트폴리오 클러치 백 디테일사진 (풀박스)', '/ArticleRead.nhn?clubid=10050146&menuid=782&articleid=860751299&query=%EB%AA%85%ED%92%88&art=aW50ZXJuYWwtY2FmZS1hcnRpY2xlLXJlYWQtaW5DYWZlLXNlYXJjaC1saXN0.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfSUQiLCJhcnRpY2xlSWQiOjg2MDc1MTI5OSwiaXNzdWVkQXQiOjE2MjkyMjg2NzU2NzYsImNhZmVJZCI6MTAwNTAxNDZ9.USs79fp8SACBb8TiyFP2rkLvaS2M0OhEwJj54Qmh2A0', '내가쩨일잘놔가', '00:21', '13')
# ...

# %%
url = "https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=782&articleid=860751838&query=%EB%AA%85%ED%92%88"

# %%
response = requests.get(url)
dom = BeautifulSoup(response.text, "html.parser")

# %%
dom.html  
dom.html.head
# Out:
# <head><title>네이버 카페</title><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no,target-densitydpi=medium-dpi,viewport-fit=cover" name="viewport"/><meta content="noindex, nofollow" name="robots"/><meta content="always" name="referrer"/><link href="https://ca-fe.pstatic.net/web-mobile/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS7_120X120_iphone.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS7_152X152_ipad_retina.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS9_167X167_ipadpro.png" rel="apple-touch-icon-precomposed" sizes="167x167"/><link href="https://cafe.pstatic.net/mobile/img/favicon2016/iOS8_180X180_iphone6plus.png" rel="apple-touch-icon-precomposed" sizes="180x180"/><link href="https://cafe.pstatic
# ...

# %%
from IPython.display import Image

# %%
content_element = dom.select_one("after")

# %%
image_elements = content_element.select("img")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e010d3135e7b> in <module>
# ----> 1 image_elements = content_element.select("img")
#
# AttributeError: 'NoneType' object has no attribute 'select'

# %%
import time
import pandas as pd
import os
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests
from datetime import date

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')
cafe_url = 'https://cafe.naver.com/joonggonara'
driver.get(cafe_url)
time.sleep(1)

# %%
page = 0
today = date.today().strftime('%Y%m%d')

driver.switch_to.frame('cafe_main')

# %%
quest_list = driver.find_elements_by_css_selector('div.inner_list > a.article')
quest_urls = [i.get_attribute('href') for i in quest_list]

# %%
for quest in quest_urls:
    page += 1
    j = 0
    # try:
    driver.get(quest)
    driver.switch_to.frame('cafe_main')

    imgs = driver.find_elements_by_name('cafeuserimg')
    img_urls = [img.get_attribute('src') for img in imgs]

        # soup = bs(driver.page_source, 'html.parser')
        # img_list = soup.select('#tbody')[0].select('img')
        # j = 0
    for img in img_urls:
        j += 1
            # source = img.src
        r = requests.get(img)
        file = open("bike_imgs/{0}_{1}_{2}.jpg".format(today, page, j), "wb")
        file.write(r.content)
        file.close()

# %%
driver.get('https://cafe.naver.com/joonggonara?iframe_url=/ArticleList.nhn%3Fsearch.clubid=10050146%26search.menuid=1009%26search.boardtype=L')
bb2 = []
dataset = []
time.sleep(2)

driver.switch_to.frame("cafe_main")
for l in range(1,5):
    tag = driver.find_elements_by_xpath('//div[@class="article-board m-tcol-c"]//table/tbody/tr')
    bb2 = tag
    time.sleep(2)
    
    for i in range(len(bb2)):
        dataset.append(bb2[i].text)

    if l % 10 == 0:
        c10 = driver.find_element_by_link_text('다음')
        c10.click()
    else:
        a = str(l+1)
        c = driver.find_element_by_link_text(a)
        c.click()
    time.sleep(2)
    
quest_list = driver.find_elements_by_css_selector('div.inner_list > a.article')
quest_urls = [i.get_attribute('href') for i in quest_list]

driver.quit()

data = len(dataset)-1
while data >= 0:
    if data % 2 == 1:
        del dataset[data]
    data-=1

list = len(dataset)-1
while list >= 0:
    if '공지' in dataset[list]:
        del dataset[list]
    list -= 1
    
    datalist = []
for r in range(len(dataset)):
    a = dataset[r].split('\n')
    if len(a) == 4:
        b = a[3].split(' ')
        del a[3]
        for i in b:
            a.append(i)
        datalist.append(a)
    elif len(a) == 6:
        b = a[5].split(' ')
        del a[5]
        for i in b:
            a.append(i)
        datalist.append(a)
    else:
        b = a[4].split(' ')
        del a[4]
        for i in b:
            a.append(i)
        datalist.append(a)
datalist

datalen = []
for r in range(len(datalist)):
    tmp = []
    tm = datalist[r]
    for t in range(len(tm)):
        if t == 3 and tm[t] != '사진':
            tmp.append('')
        tmp.append(tm[t])
        
    datalen.append(tmp)
datalen

datalen2 = datalen
shoes_dataset = []
for r in range(len(datalen2)):
    tmp = []
    tm = datalen2[r]
    for t in range(len(tm)):
        if t == 6 and tm[t] != 'new':
            tmp.append('')
        tmp.append(tm[t])
        
    shoes_dataset.append(tmp)
shoes_dataset

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
webpage = requests.get("https://www.daangn.com/search/명품")
soup = BeautifulSoup(webpage.content, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/search/%EB%AA%85%ED%92%88" rel="canonical"/>
# <title>명품 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="버버리(burberry) 정품 가죽 숄더백, &lt;&gt; 더스트백 포함, 명품 명품가방 명품백, 펜디..." name="description"/>
# <meta content="명품" name="keywords"/>
# <link href="당근마켓" rel="author"/>
# <meta content="https://www.daangn.com/search/%EB%AA%85%ED%92%88" property="og:url"/>
# <meta content="명품 중고거래 | 당신 근처의 당근마켓" property="og:title"/>
# <meta content="버버리(burberry) 정품 가죽 숄더백, &lt;&lt;새상품&gt;&gt; 더스트백 포함, 명품 명품가방 명품백, 펜디..." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/daangn.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# ...

# %%
# info = soup.findAll('div', {'class':'result-container'})
info = soup.findAll('article', {'class': "flea-market-article flat-card"})
info[0]
# Out:
# <article class="flea-market-article flat-card">
# <a class="flea-market-article-link" href="/articles/266917457">
# <div class="card-photo">
# <img alt="버버리(burberry) 정품 가죽 숄더백, &lt;&lt;새상품&gt;&gt; 더스트백 포함, 명품 명품가방 명품백" src="https://dnvefa72aowie.cloudfront.net/origin/article/202107/b9fb547488500efa4ac6108ad461fb3d475c427f80aeb0e5fc785b655f709714.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="article-info">
# <div class="article-title-content">
# <span class="article-title">버버리(burberry) 정품 가죽 숄더백, &lt;&lt;새상품&gt;&gt; 더스트백 포함, 명품 명품가방 명품백</span>
# <span class="article-content">버버리(burberry) 정품 가죽 숄더백, 더스트백 포함, 명품 명품가방 명품백
# 가격이 200만원 가까이했었습니다
# 선물받고 한번도 밖에서 사용한적없는 깨끗한 새상품
# 가죽이 고급스럽고 멋져요
# 가방 정리중이라 저렴하게 내놓아요
#
# 반품X
# 네고X</span>
# </div>
# <p class="article-region-name">
#         경기도 성남시 분당구 분당동
#       </p>
# <p class="article-price ">
#         730,000원
#       </p>
# <section class="article-sub-info">
# <span class="article-watch">
# ...

# %%
url = info[0].find('a').get('href')
print(url)

name = info[0].find('span', {'class':'article-title'}).text
print(name)

price = info[0].find('p', {'class':'article-price'}).text.strip()
print(price)
# Out:
# /articles/266917457
# 버버리(burberry) 정품 가죽 숄더백, <<새상품>> 더스트백 포함, 명품 명품가방 명품백
# 730,000원

# %%
name_list = []
price_list = []
url_list = []

for prod in info:
    name = prod.find('span', {'class':'article-title'}).text
    price = prod.find('p', {'class':'article-price'}).text.strip()
    url = prod.find('a').get('href')
    print("이름: {}, 가격: {}".format(name,price))
    name_list.append(name)
    price_list.append(price)
    url_list.append(url)
# Out:
# 이름: 버버리(burberry) 정품 가죽 숄더백, <<새상품>> 더스트백 포함, 명품 명품가방 명품백, 가격: 730,000원
# 이름: 펜디 (명품,정품) ,펜디구두,명품구두,여성구두,펜디하이힐.명품힐, 가격: 350,000원
# 이름: 명품 쇼핑백 명품 박스, 가격: 10,000원
# 이름: (마지막 명품백. 8/19까지만) 에트로 (ETRO) 토트백 가방 명품백 (원가 108만원, 정품, 품질보증서보유), 가격: 200,000원
# 이름: 정품 구찌시계 새상품급 남성명품시계 남자시계 남자명품시계, 가격: 750,000원
# 이름: (살바토레 페레가모 정품) 페레가모가방/명품백/명품 가방, 가격: 100,000원

# %%
df = pd.DataFrame({"이름" : name_list, "가격" : price_list, "url" : url_list})
df.head()
# Out:
#                                                   이름        가격  \
# 0  버버리(burberry) 정품 가죽 숄더백, <<새상품>> 더스트백 포함, 명품 명...  730,000원
# 1               펜디 (명품,정품) ,펜디구두,명품구두,여성구두,펜디하이힐.명품힐  350,000원
# 2                                       명품 쇼핑백 명품 박스   10,000원
# 3  (마지막 명품백. 8/19까지만) 에트로 (ETRO) 토트백 가방 명품백 (원가 1...  200,000원
# 4                    정품 구찌시계 새상품급 남성명품시계 남자시계 남자명품시계  750,000원
#
#                    url
# 0  /articles/266917457
# 1  /articles/212354653
# 2  /articles/264145278
# 3  /articles/272266301
# 4  /articles/271274294

# %%
response = requests.get('https://www.daangn.com' + df['url'][0])
soup = BeautifulSoup(response.content, "lxml")

# %%
bag_name = soup.find('h1',{'id':'article-title'}).text.strip()
bag_name
# Out:
# '버버리(burberry) 정품 가죽 숄더백, <<새상품>> 더스트백 포함, 명품 명품가방 명품백'

# %%
df.to_excel('crawling.xlsx')
